# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

from sklearn.svm import SVC

from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.compose import make_column_selector 
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer

from sklearn.model_selection import GridSearchCV, cross_val_score

import pickle

# %% [markdown]
# ## Dataset

# %% [markdown]
# - Each observation represents a player
# - Each column represents a characteristic of a player's performance
#
# The target defines whether the player lasted less than 5 years (`0`) vs. 5 years or more (`1`) as a professional.

# %%
data = pd.read_csv("NBA_players_data.csv")

data.head()
# Out:
#    games played  minutes played  points per game  field goals made  \
# 0          36.0            27.4              7.4               2.6
# 1          35.0            26.9              NaN               2.0
# 2           NaN            15.3              5.2               2.0
# 3          58.0            11.6              5.7               2.3
# 4          48.0            11.5              4.5               1.6
#
#    field goal attempts  field goal percent  3 point made  3 point attempt  \
# 0                  7.6                 NaN           0.5              2.1
# 1                  6.7                29.6           0.7              2.8
# 2                  4.7                42.2           0.4              1.7
# 3                  5.5                42.6           0.1              0.5
# 4                  3.0                52.4           0.0              0.1
#
#    3 point %  free throw made  free throw attempts  free throw %  \
# 0       25.0              1.6                  2.3          69.9
# 1       23.5              2.6                  3.4          76.5
# 2       24.4              0.9                  1.3          67.0
# 3       22.6              0.9                  1.3          68.9
# 4        0.0              1.3                  1.9          67.4
#
#    offensive rebounds  defensive rebounds  rebounds  assists  steals  blocks  \
# 0                 0.7                 3.4       4.1      1.9     0.4     0.4
# 1                 0.5                 2.0       2.4      3.7     1.1     0.5
# 2                 0.5                 1.7       2.2      1.0     0.5     0.3
# 3                 1.0                 0.9       1.9      0.8     0.6     0.1
# 4                 1.0                 1.5       2.5      0.3     0.3     0.4
#
#    turnovers  target_5y
# 0        1.3          0
# 1        1.6          0
# 2        1.0          0
# 3        1.0          1
# 4        0.8          1

# %%
df = data.copy()

# %%
X = df.drop(columns='target_5y', axis=1)
y = df.target_5y

# %% [markdown]
# ## Pipeline

# %%
# Create a variable with the numerical columns 
num_columns = make_column_selector(dtype_include=['float64','int64'])

# Create a variable with the categorical columns 
cat_columns = make_column_selector(dtype_include=['object','bool'])

# Create a pipeline that has the desired transformations for the numerical columns
num_transformer = make_pipeline(SimpleImputer(), MinMaxScaler())

# Instantiate the desired transformations for the categorical columns
cat_transformer = OneHotEncoder(handle_unknown='ignore', sparse=False)

preprocessor = make_column_transformer(
		(num_transformer, num_columns),
    (cat_transformer, cat_columns),
    remainder='passthrough'
)

pd.DataFrame(preprocessor.fit_transform(X), 
             columns=preprocessor.get_feature_names_out())
# Out:
#      pipeline__games played  pipeline__minutes played  \
# 0                  0.591549                  0.247283
# 1                  0.619718                  0.616848
# 2                  0.901408                  0.296196
# 3                  0.802817                  0.331522
# 4                  1.000000                  0.758152
# ..                      ...                       ...
# 933                0.408451                  0.086957
# 934                0.661972                  0.448370
# 935                0.859155                  0.211957
# 936                0.352113                  0.279891
# 937                0.591549                  0.119565
#
#      pipeline__points per game  pipeline__field goals made  \
# 0                     0.146520                    0.181818
# 1                     0.227106                    0.252525
# 2                     0.172161                    0.181818
# 3                     0.106227                    0.131313
# 4                     0.637363                    0.737374
# ..                         ...                         ...
# 933                   0.047619                    0.050505
# 934                   0.238095                    0.282828
# 935                   0.073260                    0.090909
# 936                   0.179487                    0.202020
# 937                   0.080586                    0.090909
#
#      pipeline__field goal attempts  pipeline__field goal percent  \
# 0                         0.163158                      0.593186
# 1                         0.336842                      0.292585
# 2                         0.210526                      0.384770
# 3                         0.184211                      0.292585
# 4                         0.700000                      0.609218
# ..                             ...                           ...
# 933                       0.078947                      0.206413
# 934                       0.305263                      0.456914
# 935                       0.078947                      0.543086
# 936                       0.242105                      0.386774
# 937                       0.073684                      0.559118
#
#      pipeline__3 point made  pipeline__3 point attempt  pipeline__3 point %  \
# 0                  0.000000                   0.000000             0.000000
# 1                  0.043478                   0.061538             0.238000
# 2                  0.000000                   0.000000             0.000000
# 3                  0.086957                   0.169231             0.192000
# 4                  0.173913                   0.169231             0.341000
# ..                      ...                        ...                  ...
# 933                0.000000                   0.046154             0.083000
# 934                0.000000                   0.030769             0.222000
# 935                0.000000                   0.000000             0.195199
# 936                0.000000                   0.015385             0.500000
# 937                0.000000                   0.000000             0.000000
#
#      pipeline__free throw made  pipeline__free throw attempts  \
# 0                     0.092105                       0.100000
# 1                     0.184211                       0.188889
# 2                     0.171053                       0.211111
# 3                     0.026316                       0.033333
# 4                     0.342105                       0.366667
# ..                         ...                            ...
# 933                   0.078947                       0.100000
# 934                   0.157895                       0.177778
# 935                   0.052632                       0.122222
# 936                   0.131579                       0.144444
# 937                   0.092105                       0.111111
#
#      pipeline__free throw %  pipeline__offensive rebounds  \
# 0                  0.683473                      0.309524
# 1                  0.742297                      0.166667
# 2                  0.589636                      0.166667
# 3                  0.500000                      0.261905
# 4                  0.735294                      0.666667
# ..                      ...                           ...
# 933                0.557423                      0.047619
# 934                0.693277                      0.476190
# 935                0.242297                      0.238095
# 936                0.747899                      0.261905
# 937                0.631653                      0.142857
#
#      pipeline__defensive rebounds  pipeline__rebounds  pipeline__assists  \
# 0                        0.202128            0.222222           0.096774
# 1                        0.244681            0.207407           0.698925
# 2                        0.212766            0.185185           0.096774
# 3                        0.191489            0.200000           0.096774
# 4                        0.797872            0.748148           0.215054
# ..                            ...                 ...                ...
# 933                      0.031915            0.022222           0.053763
# 934                      0.414894            0.422222           0.129032
# 935                      0.138298            0.155556           0.064516
# 936                      0.127660            0.148148           0.096774
# 937                      0.127660            0.118519           0.010753
#
#      pipeline__steals  pipeline__blocks  pipeline__turnovers
# 0                0.16          0.057143             0.170732
# 1                0.44          0.028571             0.585366
# 2                0.20          0.257143             0.365854
# 3                0.12          0.114286             0.146341
# 4                0.28          0.485714             0.512195
# ..                ...               ...                  ...
# 933              0.12          0.028571             0.146341
# 934              0.20          0.171429             0.292683
# 935              0.12          0.200000             0.146341
# 936              0.12          0.057143             0.195122
# 937              0.04          0.028571             0.121951
#
# [938 rows x 19 columns]

# %%
final_pipeline = make_pipeline(preprocessor, SVC())

# %%
final_pipeline.get_params()

# %% [markdown]
# ## Adjusting the Pipeline

# %% [markdown]
# We will try to find the best parameters for the model and the best input strategy.
# <br>
# We also use a 'Precision' scoring metric to avoid false alarms.

# %%
final_pipeline = make_pipeline(preprocessor, SVC())

final_pipeline

## Hyperparameters are called with:
# the name of the feature + double underscore + name of the hyperparameter
grid_params = {'svc__C' : np.arange(0.1,1, 0.1), 
               'svc__kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
               'columntransformer__pipeline__simpleimputer__strategy': ['mean', 'median', 'most_frequent']}

# Instantiate Grid Search
grid = GridSearchCV(final_pipeline, grid_params, n_jobs=-1, scoring = "precision", cv = 5)

# %%
grid.fit(X, y)

print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'columntransformer__pipeline__simpleimputer__strategy': 'mean', 'svc__C': 0.4, 'svc__kernel': 'poly'}
# 0.7630538676291507

# %% [markdown]
# Storing the results in a variable

# %%
# Save in a variable the best parameters
best_pipeline = grid.best_estimator_

# %%
# Cross Validate the Dataset with the best parameters
scores = cross_val_score(best_pipeline, X,y,cv=5, scoring="precision")
score = scores.mean()

print(scores)
print(f'\nThe mean score is: {scores.mean()}')
# Out:
# [0.74358974 0.76315789 0.79285714 0.75316456 0.7625    ]
#
# The mean score is: 0.7630538676291507

# %% [markdown]
# ## Export

# %% [markdown]
# Once the best parameters found, we export the pipeline as a pickle file

# %%
# Export pipeline as pickle file
with open("pipeline.pkl", "wb") as file:
    pickle.dump(best_pipeline, file)
